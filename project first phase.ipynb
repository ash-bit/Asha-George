# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Provisional_COVID-19_Death_Counts_by_Sex__Age__and_State.csv')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ASHA\\Desktop\\python'

# %%
df
# Out:
#       Data as of  Start week    End Week              State      Sex  \
# 0     08/19/2020  02-01-2020  08/15/2020      United States      All
# 1     08/19/2020  03-01-2020  08/15/2020      United States      All
# 2     08/19/2020  04-01-2020  08/15/2020      United States      All
# 3     08/19/2020  05-01-2020  08/15/2020      United States      All
# 4     08/19/2020  06-01-2020  08/15/2020      United States      All
# ...          ...         ...         ...                ...      ...
# 1411  08/19/2020  02-01-2020  08/15/2020        Puerto Rico   Female
# 1412  08/19/2020  02-01-2020  08/15/2020        Puerto Rico   Female
# 1413  08/19/2020  02-01-2020  08/15/2020        Puerto Rico   Female
# 1414  08/19/2020  02-01-2020  08/15/2020        Puerto Rico  Unknown
# 1415  08/19/2020  02-01-2020  08/15/2020  Puerto Rico Total      All
#
#               Age group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# ...

# %%
df.dtypes
# Out:
# Data as of                                   object
# Start week                                   object
# End Week                                     object
# State                                        object
# Sex                                          object
# Age group                                    object
# COVID-19 Deaths                             float64
# Total Deaths                                float64
# Pneumonia Deaths                            float64
# Pneumonia and COVID-19 Deaths               float64
# Influenza Deaths                            float64
# Pneumonia, Influenza, or COVID-19 Deaths    float64
# Footnote                                     object
# dtype: object

# %%
df.groupby('Age group')['Total Deaths'].count()
# Out:
# Age group
# 1-4 years             64
# 15-24 years          106
# 25-34 years          109
# 35-44 years          109
# 45-54 years          109
# 5-14 years            77
# 55-64 years          109
# 65-74 years          109
# 75-84 years          109
# 85 years and over    109
# All ages             193
# Under 1 year         103
# Name: Total Deaths, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.countplot(x = df['Age group'])
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.swarmplot(x = 'Age group', y = 'Total Deaths', data = df)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1311: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1315: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
states = list(set(df['State']))
states
# Out:
# ['Louisiana Total',
#  'Delaware Total',
#  'Massachusetts Total',
#  'South Carolina Total',
#  'Nebraska',
#  'California',
#  'Connecticut Total',
#  'Montana',
#  'New Jersey Total',
#  'Oklahoma Total',
#  'South Dakota',
#  'Virginia Total',
#  'Arkansas Total',
#  'Oregon',
#  'Pennsylvania Total',
#  'Washington Total',
#  'Louisiana',
#  'Maine',
#  'Oklahoma',
#  'Nevada Total',
#  'New York City',
#  'Massachusetts',
#  'Mississippi',
#  'Ohio',
#  'Wisconsin',
#  'Vermont Total',
#  'Idaho',
#  'North Dakota',
#  'California Total',
#  'Utah Total',
#  'New Hampshire Total',
#  'Minnesota',
#  'Puerto Rico',
#  'North Dakota Total',
#  'Montana Total',
#  'Mississippi Total',
#  'Iowa',
#  'Illinois Total',
#  'Maryland Total',
#  'Alabama',
#  'Michigan Total',
#  'Colorado',
#  'Idaho Total',
#  'Texas',
#  'Indiana Total',
#  'Michigan',
#  'West Virginia',
#  'Alaska Total',
#  'South Carolina',
#  'Texas Total',
#  'Minnesota Total',
#  'Kentucky',
#  'Georgia',
# ...

# %%
plt.figure(figsize = (12,8))
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.stripplot(x = 'Age group', y = 'COVID-19 Deaths', data = df)
plt.show()

# %%
df.groupby('Age group')['COVID-19 Deaths']

# %%
sns.heatmap(df.corr())
